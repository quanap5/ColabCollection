# %% [markdown]
# <a href="https://colab.research.google.com/github/quanap5/ColabCollection/blob/main/Sentence_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentence-transformers

# %%
from transformers.utils import logging
logging.set_verbosity_error()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
sentences1 = ['Pyton is under my bed',
             'A man is sitting on a porch',
             'The movies are so boring']

# %%
embeddings1 = model.encode(sentences1, convert_to_tensor=True)

# %%
embeddings1

# %%
sentences2 = ['The snake is under my bed',
              'A woman is sitting on a porch',
              'The new movie made me sleepy']

# %%
embeddings2 = model.encode(sentences2,
                           convert_to_tensor=True)

# %%
print(embeddings2)

# %%
from sentence_transformers import util

# %%
cosine_scores = util.cos_sim(embeddings1, embeddings2)

# %%
print(cosine_score)

# %%
for i in range(len(sentences1)):
    print("{} \t\t {} \t\t Score: {:.4f}".format(sentences1[i],
                                                 sentences2[i],
                                                 cosine_scores[i][i]))

# %% [markdown]
# ### Reference
#
# - https://colab.research.google.com/drive/1nDKqguq2VABoRkzMMm9fDxN9G8mznOZ5#scrollTo=uISC3Dfa2Nd7

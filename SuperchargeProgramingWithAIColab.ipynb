# %% [markdown]
# <a href="https://colab.research.google.com/github/quanap5/ColabCollection/blob/main/SuperchargeProgramingWithAIColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Midterm_Grade

from matplotlib import pyplot as plt
df_grades_new['Midterm_Grade'].plot(kind='line', figsize=(8, 4), title='Midterm_Grade')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # List available models
#
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text

# %%
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-2.0-flash',
#  'google/gemini-2.0-flash-lite',
#  'google/gemini-2.5-flash',
#  'google/gemini-2.5-flash-lite',
#  'google/gemini-2.5-pro',
#  'google/gemma-3-12b',
#  'google/gemma-3-1b',
#  'google/gemma-3-27b',
#  'google/gemma-3-4b']

# %% [markdown]
# # Simple batch generation example

# %%
from google.colab import ai

response = ai.generate_text("What is the capital of England", model_name='google/gemini-2.0-flash-lite')
print(response)
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# /tmp/ipython-input-4-3424904400.py in <cell line: 0>()
#       1 from google.colab import ai
#       2
# ----> 3 response = ai.generate_text("What is the capital of ENgland", model_name='google/gemini-2.0-flash-lite')
#       4 print(response)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/ai.py in generate_text(prompt, model_name, stream)
#      83   )
#      84
# ---> 85   response = client.chat.completions.create(
#      86       model=model_name,
#      87       messages=[{'role': 'user', 'content': prompt}],
#
# /usr/local/lib/python3.11/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     285                         msg = f"Missing required argument: {quote(missing[0])}"
#     286                 raise TypeError(msg)
# --> 287             return func(*args, **kwargs)
#     288
# ...
